# %% [markdown]
# # ICE Training Data Extraction Experiment (no model access)

# %%
import pandas as pd
import sklearn.ensemble as es
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
from sklearn.inspection import partial_dependence
from sklearn.inspection import PartialDependenceDisplay
import numpy as np
import logging
import time

# %%
# %run experiment_setup.ipynb

# %% [markdown]
# This notebook will go through the experiment for training data extraction with individual conditional expectation (ICE). The experiments will be performed without attacker access to the model. Training data extraction means an attacker can find out the feature values of samples from the training data without prior knowledge of them. The attacker only has access to the explanation.
#
# The idea for ICE training data extraction is as follows: The attacker can check which predictions values are the same for different ICE lines from the same training sample (each training sample has one ICE line for every feature). If there is only one possible combination of feature values with the same prediction value, then these feature values must make up the original sample. If multiple possibilites exist, then an unambiguous extraction is impossible (without access to the model). In this case the sample cannot be extracted by the attacker.
#
# First, we define a few functions that will help us run the experiment later.

# %% [markdown]
# The function can execute training data extraction for ICE explanations. It takes a list of ICE explanations (for different features) and the number of extractions to attempt. The function returns a list of succesfully extracted samples. The precision and reacll of the extraction is tested in the following experiments.

# %%
class ICETDE(XaiPrivacyExperiment):
    def train_explainer(self, data_train, model):
        # Calculate ICE
        ice_features = []

        x_train = data_train.drop(self.outcome_name, axis=1)
        num_samples = len(x_train)
        
        for i in range(self.features.shape[1]):
            ice_features.append(partial_dependence(estimator=model, X=x_train, features=[i], percentiles=(0,1),\
                                                   grid_resolution=num_samples + 1, kind='individual'))
            
        return ice_features
        
    @staticmethod
    def training_data_extraction_no_model_access(explainer, stop_after, feature_formats, rng):
        # Get all feature names
        feature_names = []
        
        for feature in feature_formats:
            feature_names.append(feature['name'])
            
        # better parameter name
        ice_features = explainer
        
        # Collect all extracted samples in this list
        extracted_samples = []

        # Get proper number of extractions to attempt based on input.
        if stop_after is None:
            index_range = len(ice_features[0]['individual'][0])
        else:
            index_range = stop_after

        # Attempt extraction for each sample until index_range
        for sample_index in range(index_range):

            num_of_features = len(ice_features)

            # Create array that contains all predictions values that are shared across all ICE lines for this sample.
            shared_preds = ice_features[0]['individual'][0][sample_index]
            for i in range(num_of_features):
                shared_preds = np.intersect1d(shared_preds, ice_features[i]['individual'][0][sample_index])

            # If the lines share no prediction values then they cannot be part of the same sample (they must at least share
            # one prediction value: the original prediction value of the sample).
            if len(shared_preds) == 0:
                logging.debug(f'Sample index {sample_index}: No extraction possible: There are no shared prediction values.')
                continue

            # If the lines share multiple prediction values then the attacker cannot be sure which one belongs to the original 
            # sample. Extraction is aborted because it is not possible to extract a single definite sample.
            if len(shared_preds) > 1:
                logging.debug(f'Sample index {sample_index}: Unambiguous extraction impossible: Multiple shared prediction values: {shared_preds}')
                continue

            logging.debug(f'Sample index {sample_index}: Shared prediction value: {shared_preds[0]}')

            # This array will contain the feature values where the shared prediction value occurs. This the extracted sample.
            extracted_sample = np.zeros(num_of_features)

            # This boolean tracks whether an unambiguous extraction is still possible. It becomes False if there are multiple
            # feature values for one feature for the shared prediction value. In that case, no unambiguous extraction is possible
            # anymore.
            unambiguous_extraction_possible = True

            for i in range(num_of_features):

                # Get indices where the ICE lines prediction is equal to the shared prediction.
                indices = np.where(ice_features[i]['individual'][0][sample_index] == shared_preds[0])[0]

                # If multiple feature values for one feature with the shared prediction value occur, then unamiguous extraction
                # is no longer possible. Abort the extraction process for this sample.
                if len(indices) > 1:
                    unambiguous_extraction_possible = False
                    break

                # Get the feature value for index with shared prediction value and add it to the extracted sample.
                values = ice_features[i]['values'][0][indices]
                extracted_sample[i] = values[0]

            # Abort extraction process if unambiguous extraction is not possible
            if not unambiguous_extraction_possible:
                logging.debug("Sample index %s: Unambiguous extraction impossible (multiple values for shared prediction)." \
                              % (sample_index))
                continue

            extracted_samples.append(extracted_sample)

            logging.debug(f'Sample index {sample_index}: Extracted sample: {extracted_sample}')

        extracted_samples_df = pd.DataFrame(extracted_samples, columns=feature_names)
            
        # Return all extracted samples
        return extracted_samples_df

# %% [markdown]
# # Dataset 1: Heart Disease

# %% [markdown]
# Before running the experiment, we we will have a short look at the visual explanation of ICE. The underlying data of these graphs will be our attack vector for training data extraction.
#
# The dark blue lines represent the average change in predictions for a change in the specified feature. The light blue lines are the change in prediction for single samples from the training data. These are the ICE lines for individual samples from the training data.

# %%
# Train a random forest on training data.
features = data_num.drop(outcome_name_num, axis=1)
labels = data_num[outcome_name_num]

model = es.RandomForestClassifier(random_state=0)
model = model.fit(features, labels)

num_of_features = 8

fig, ax = plt.subplots(figsize=(14, 14))

display = PartialDependenceDisplay.from_estimator(
       model, features, continuous_features_num, kind="both", subsample=10,
       n_jobs=3, grid_resolution=20, random_state=0, percentiles = (0.05, 0.95), ax=ax
)

# %% [markdown]
# As a proof of concept for our privacy attack, we run the experiment for a few iterations with logging to show how the training data extraction function works in principle.

# %%
start = time.time()

logging.root.setLevel(logging.DEBUG)

EXP = ICETDE(data_num, continuous_features_num, outcome_name_num, 0)
EXP.training_data_extraction_experiment(10, MLPClassifier(hidden_layer_sizes=(32, 32, 32), random_state=0), model_access=False)

logging.root.setLevel(logging.INFO)

print("--- %s seconds ---" % (time.time() - start))
# Out:
# DEBUG:root:Sample index 0: Shared prediction value: 0.060264966611817315
# DEBUG:root:Sample index 0: Extracted sample: [ 39.     0.   195.   106.    70.    26.97  80.    77.  ]
# DEBUG:root:Sample index 1: Shared prediction value: 0.057950182847696
# DEBUG:root:Sample index 1: Extracted sample: [ 46.     0.   250.   121.    81.    28.73  95.    76.  ]
# DEBUG:root:Sample index 2: Shared prediction value: 0.16637318249759395
# DEBUG:root:Sample index 2: Extracted sample: [ 48.    20.   245.   127.5   80.    25.34  75.    70.  ]
# DEBUG:root:Sample index 3: Shared prediction value: 0.3218303010516997
# DEBUG:root:Sample index 3: Extracted sample: [ 61.    30.   225.   150.    95.    28.58  65.   103.  ]
# DEBUG:root:Sample index 4: Shared prediction value: 0.10337684379161685
# DEBUG:root:Sample index 4: Extracted sample: [ 46.   23.  285.  130.   84.   23.1  85.   85. ]
# DEBUG:root:Sample index 5: Shared prediction value: 0.1035166436388026
# DEBUG:root:Sample index 5: Extracted sample: [ 43.    0.  228.  180.  110.   30.3  77.   99. ]
# DEBUG:root:Sample index 6: Shared prediction value: 0.3010597904024079
# DEBUG:root:Sample index 6: Extracted sample: [ 63.     0.   205.   138.    71.    33.11  60.    85.  ]
# DEBUG:root:Sample index 7: Shared prediction value: 0.15313798196418474
# DEBUG:root:Sample index 7: Extracted sample: [ 45.    20.   313.   100.    71.    21.68  79.    78.  ]
# DEBUG:root:Sample index 8: Shared prediction value: 0.12036467518775663
# DEBUG:root:Sample index 8: Extracted sample: [ 52.     0.   260.   141.5   89.    26.36  76.    79.  ]
# DEBUG:root:Sample index 9: Shared prediction value: 0.14682786565973097
# DEBUG:root:Sample index 9: Extracted sample: [ 43.    30.   225.   162.   107.    23.61  93.    88.  ]
# DEBUG:root:Extracted sample: [ 39.     0.   195.   106.    70.    26.97  80.    77.  ]
# DEBUG:root:Appears in training data at indices [367]
# DEBUG:root:Extracted sample: [ 43.    0.  228.  180.  110.   30.3  77.   99. ]
# DEBUG:root:Appears in training data at indices [1003]
# DEBUG:root:Extracted sample: [ 43.    30.   225.   162.   107.    23.61  93.    88.  ]
# DEBUG:root:Appears in training data at indices [1104]
# DEBUG:root:Extracted sample: [ 45.    20.   313.   100.    71.    21.68  79.    78.  ]
# DEBUG:root:Appears in training data at indices [1402]
# DEBUG:root:Extracted sample: [ 46.     0.   250.   121.    81.    28.73  95.    76.  ]
# DEBUG:root:Appears in training data at indices [1465]
# DEBUG:root:Extracted sample: [ 46.   23.  285.  130.   84.   23.1  85.   85. ]
# DEBUG:root:Appears in training data at indices [1564]
# DEBUG:root:Extracted sample: [ 48.    20.   245.   127.5   80.    25.34  75.    70.  ]
# DEBUG:root:Appears in training data at indices [1829]
# DEBUG:root:Extracted sample: [ 52.     0.   260.   141.5   89.    26.36  76.    79.  ]
# DEBUG:root:Appears in training data at indices [2289]
# DEBUG:root:Extracted sample: [ 61.    30.   225.   150.    95.    28.58  65.   103.  ]
# DEBUG:root:Appears in training data at indices [3369]
# DEBUG:root:Extracted sample: [ 63.     0.   205.   138.    71.    33.11  60.    85.  ]
# DEBUG:root:Appears in training data at indices [3473]
# Number of extracted samples: 10
# Number of accurate extracted samples: 10
# Precision: 1.0, recall: 1.0
# --- 10.175264120101929 seconds ---

# %% [markdown]
# The proof of concept should show that the training data extraction function is unable to extract samples for this dataset because no unambiguous extractions are possible. We will later see a dataset and model combination where the extraction is succesfull.

# %% [markdown]
# Now we execute the entire experiment for this dataset.

# %%
results_ = {'dataset': [], 'model': [], 'precision': [], 'recall': []}

results = pd.DataFrame(data = results_)

# %%
print("features: continuous, model: decision tree.")

start_time = time.time()

EXP = ICETDE(data_num, continuous_features_num, outcome_name_num, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            DecisionTreeClassifier(random_state=0), model_access=False)


results.loc[len(results.index)] = ['continuous', 'decision tree', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: continuous, model: decision tree.
# Number of extracted samples: 0
# Number of accurate extracted samples: 0
# Precision: nan, recall: 0.0
# --- 5.7688844203948975 seconds ---

# %%
print("features: continuous, model: random forest.")

start_time = time.time()

EXP = ICETDE(data_num, continuous_features_num, outcome_name_num, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            es.RandomForestClassifier(random_state=0), model_access=False)

results.loc[len(results.index)] = ['continuous', 'random forest', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: continuous, model: random forest.
# Number of extracted samples: 4
# Number of accurate extracted samples: 4
# Precision: 1.0, recall: 0.0010526315789473684
# --- 120.56368207931519 seconds ---

# %%
print("features: continuous, model: neural network.")

start_time = time.time()

EXP = ICETDE(data_num, continuous_features_num, outcome_name_num, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            MLPClassifier(hidden_layer_sizes=(32, 32, 32), random_state=0), model_access=False)

results.loc[len(results.index)] = ['continuous', 'neural network', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: continuous, model: neural network.
# Number of extracted samples: 3800
# Number of accurate extracted samples: 3800
# Precision: 1.0, recall: 1.0
# --- 14.036472082138062 seconds ---

# %% [markdown]
# # Dataset 2: Census Income

# %% [markdown]
# Now all variations of the training data extraction experiment will be executed for the second dataset.

# %%
print("features: categorical, model: decision tree.")

start_time = time.time()

EXP = ICETDE(data_cat, continuous_features_cat, outcome_name_cat, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            DecisionTreeClassifier(random_state=0), model_access=False)

results.loc[len(results.index)] = ['categorical', 'decision tree', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: categorical, model: decision tree.
# Number of extracted samples: 0
# Number of accurate extracted samples: 0
# Precision: nan, recall: 0.0
# --- 2.67622971534729 seconds ---

# %%
print("features: categorical, model: random forest.")

start_time = time.time()

EXP = ICETDE(data_cat, continuous_features_cat, outcome_name_cat, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            es.RandomForestClassifier(random_state=0), model_access=False)

results.loc[len(results.index)] = ['categorical', 'random forest', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: categorical, model: random forest.
# Number of extracted samples: 4172
# Number of accurate extracted samples: 4172
# Precision: 1.0, recall: 0.5402745402745402
# --- 22.29656958580017 seconds ---

# %%
print("features: categorical, model: neural network.")

start_time = time.time()

EXP = ICETDE(data_cat, continuous_features_cat, outcome_name_cat, 0)
precision, recall = EXP.training_data_extraction_experiment(None,\
                            MLPClassifier(hidden_layer_sizes=(32, 32, 32), random_state=0), model_access=False)

results.loc[len(results.index)] = ['categorical', 'neural network', precision, recall]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# features: categorical, model: neural network.
# Number of extracted samples: 7720
# Number of accurate extracted samples: 7720
# Precision: 1.0, recall: 0.9997409997409997
# --- 20.321028470993042 seconds ---

# %% [markdown]
# # Results
#
# The results of all variations of the training data extraction experiment with ICE. In each experiment, sample extraction was attempted for each sample in the training data.
#
# Precision measures the precentage of extracted samples that actually appear in the training data.
#
# Recall measures the percentage of training samples that were succesfully extracted by the attack.

# %%
results
# Out:
#        dataset           model  precision    recall
# 0   continuous   decision tree        NaN  0.000000
# 1   continuous   random forest        1.0  0.001053
# 2   continuous  neural network        1.0  1.000000
# 3  categorical   decision tree        NaN  0.000000
# 4  categorical   random forest        1.0  0.540275
# 5  categorical  neural network        1.0  0.999741

# %%
results.to_csv('results/ice-training-data-extraction-results.csv', index=False, na_rep='NaN')
